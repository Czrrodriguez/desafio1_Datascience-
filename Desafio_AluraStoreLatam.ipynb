# %% [markdown]
# <a href="https://colab.research.google.com/github/Czrrodriguez/desafio1_Datascience-/blob/main/Desafio_AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
print(tienda.columns)
# Out:
# Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'],
#       dtype='object')

# %% [markdown]
# Comenzamos Conociendo cuales eran nuestras "celdas" para trabajar

# %%
# Sumar la facturación (Columna de Precio) de cada tienda
facturacion_tienda1 = tienda['Precio'].sum()
facturacion_tienda2 = tienda2['Precio'].sum()
facturacion_tienda3 = tienda3['Precio'].sum()
facturacion_tienda4 = tienda4['Precio'].sum()

# Con esto vamos a mostrar la facturación de cada tienda
print(f"Facturación Tienda 1: ${facturacion_tienda1:,.2f}")
print(f"Facturación Tienda 2: ${facturacion_tienda2:,.2f}")
print(f"Facturación Tienda 3: ${facturacion_tienda3:,.2f}")
print(f"Facturación Tienda 4: ${facturacion_tienda4:,.2f}")

# Facturación total de todas las tiendas
facturacion_total = facturacion_tienda1 + facturacion_tienda2 + facturacion_tienda3 + facturacion_tienda4
print(f"Facturación Total: ${facturacion_total:,.2f}")
# Out:
# Facturación Tienda 1: $1,150,880,400.00
# Facturación Tienda 2: $1,116,343,500.00
# Facturación Tienda 3: $1,098,019,600.00
# Facturación Tienda 4: $1,038,375,700.00
# Facturación Total: $4,403,619,200.00

# %% [markdown]
# # 2. Ventas por categoría

# %%
#Agrupar las ventas por la columna (categoria del producto)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Agrupar por categoría y sumar las ventas
ventas_por_categoria = tienda.groupby('Categoría del Producto')['Precio'].sum().reset_index()

# Ordenar las categorías de mayor a menor
ventas_por_categoria = ventas_por_categoria.sort_values('Precio', ascending=False)

# Mostrar el resultado
print(ventas_por_categoria)

# Graficar las ventas por categoría
plt.figure(figsize=(10,6))
sns.barplot(x='Precio', y='Categoría del Producto', data=ventas_por_categoria, hue='Categoría del Producto', palette='viridis', legend=False)

# Mejorar el gráfico

# Mejorar el gráfico
plt.title('Ventas por Categoría de Producto', fontsize=16)
plt.xlabel('Ventas Totales ($)', fontsize=12)
plt.ylabel('Categoría de Producto', fontsize=12)
plt.tight_layout()

# Mostrar
plt.show()
# Out:
#     Categoría del Producto       Precio
# 3             Electrónicos  429493500.0
# 2        Electrodomésticos  363685200.0
# 7                  Muebles  187633700.0
# 4   Instrumentos musicales   91299000.0
# 1     Deportes y diversión   39290000.0
# 5                 Juguetes   17995700.0
# 0  Artículos para el hogar   12698400.0
# 6                   Libros    8784900.0

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
# Calcular la calificación promedio de cada tienda
calificacion_tienda1 = tienda['Calificación'].mean()
calificacion_tienda2 = tienda2['Calificación'].mean()
calificacion_tienda3 = tienda3['Calificación'].mean()
calificacion_tienda4 = tienda4['Calificación'].mean()

# Mostrar el resultado
print(f"Calificación promedio Tienda 1: {calificacion_tienda1:.2f}")
print(f"Calificación promedio Tienda 2: {calificacion_tienda2:.2f}")
print(f"Calificación promedio Tienda 3: {calificacion_tienda3:.2f}")
print(f"Calificación promedio Tienda 4: {calificacion_tienda4:.2f}")

# Crear un DataFrame para graficar las calificaciones
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
calificaciones = [calificacion_tienda1, calificacion_tienda2, calificacion_tienda3, calificacion_tienda4]

# Graficar las calificaciones promedio por tienda
plt.figure(figsize=(10,6))
sns.barplot(x='Tienda', y='Calificación Promedio', data=pd.DataFrame({'Tienda': tiendas, 'Calificación Promedio': calificaciones}), hue='Tienda', palette='Blues_d', legend=False)


# Mejorar el gráfico
plt.title('Calificación Promedio por Tienda', fontsize=16)
plt.xlabel('Tienda', fontsize=12)
plt.ylabel('Calificación Promedio', fontsize=12)
plt.tight_layout()


# Mostrar
plt.show()
# Out:
# Calificación promedio Tienda 1: 3.98
# Calificación promedio Tienda 2: 4.04
# Calificación promedio Tienda 3: 4.05
# Calificación promedio Tienda 4: 4.00

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
# Agrupar por producto y sumar la cantidad de ventas
productos_ventas = tienda.groupby('Producto')['Cantidad de cuotas'].sum().reset_index()

# Ordenar los productos de mayor a menor
productos_ventas = productos_ventas.sort_values('Cantidad de cuotas', ascending=False)

# Mostrar los productos más vendidos y los menos vendidos
# Los 10 productos más vendidos
print("Productos más vendidos:\n")
print(productos_ventas.head(10))

# Los 10 productos menos vendidos
print("\nProductos menos vendidos:\n")
print(productos_ventas.tail(10))

# Graficar los productos más vendidos
plt.figure(figsize=(12,8))
sns.barplot(x='Cantidad de cuotas', y='Producto', data=productos_ventas.head(10), hue='Producto', palette='viridis', legend=False)

# Mejorar el gráfico
plt.title('Productos Más Vendidos', fontsize=16)
plt.xlabel('Cantidad de Unidades Vendidas', fontsize=12)
plt.ylabel('Producto', fontsize=12)
plt.tight_layout()

# Mostrar
plt.show()
# Out:
# Productos más vendidos:
#
#                    Producto  Cantidad de cuotas
# 40         Secadora de ropa                 214
# 48            TV LED UHD 4K                 196
# 32            Mesa de noche                 188
# 23                Impresora                 182
# 8                 Bicicleta                 178
# 5       Balón de baloncesto                 167
# 22       Guitarra eléctrica                 167
# 47          Sofá reclinable                 163
# 43         Silla de oficina                 161
# 9   Bloques de construcción                 161
#
# Productos menos vendidos:
#
#                      Producto  Cantidad de cuotas
# 24  Iniciando en programación                 113
# 37            Olla de presión                 108
# 4   Auriculares con micrófono                 103
# 42               Set de vasos                 101
# 16            Cubo mágico 8x8                 101
# 17         Cuerda para saltar                 100
# ...

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
# Agrupar por tienda y calcular el costo promedio de envío
envio_promedio = tienda.groupby('Lugar de Compra')['Costo de envío'].mean().reset_index()

# Redondear a 2 decimales
envio_promedio['Costo de envío'] = envio_promedio['Costo de envío'].round(2)

# Ordenar por el costo de envío promedio de mayor a menor
envio_promedio = envio_promedio.sort_values('Costo de envío', ascending=False)

# Mostrar los costos promedio de envío
print(envio_promedio)

# Graficar el costo de envío promedio por tienda
plt.figure(figsize=(12,8))
grafico = sns.barplot(x='Costo de envío', y='Lugar de Compra', data=envio_promedio, hue='Lugar de Compra', palette='coolwarm', legend=False)

# Agregar los valores encima de cada barra
for container in grafico.containers:
    grafico.bar_label(container, fmt='%.2f', label_type='edge', padding=3)

# Mejorar el gráfico
plt.title('Costo Promedio de Envío por Tienda', fontsize=16)
plt.xlabel('Costo de Envío Promedio (USD)', fontsize=12)
plt.ylabel('Tienda', fontsize=12)
plt.tight_layout()

# Mostrar
plt.show()
# Out:
#    Lugar de Compra  Costo de envío
# 16          Soacha        43420.00
# 6           Cúcuta        40129.41
# 12           Pasto        35078.26
# 18   Villavicencio        34709.09
# 11           Neiva        31516.67
# 3      Bucaramanga        30587.10
# 9        Manizales        29140.00
# 4             Cali        28827.56
# 7          Inírida        28460.00
# 10        Medellín        28207.10
# 8          Leticia        24450.00
# 14        Riohacha        24357.50
# 2           Bogotá        23815.85
# 1     Barranquilla        23708.00
# 5        Cartagena        22624.53
# 15     Santa Marta        22593.75
# 13         Pereira        22403.76
# 17      Valledupar        18766.67
# 0          Armenia        17314.29

# %% [markdown]
# *RESUMEN EXPLICATIVO PRA EL CLIENTE*

# %%
# Facturación total por tienda
facturacion = tienda.groupby('Lugar de Compra')['Precio'].sum()

# Calificación promedio por tienda
calificacion = tienda.groupby('Lugar de Compra')['Calificación'].mean()

# Costo de envío promedio por tienda
envio = tienda.groupby('Lugar de Compra')['Costo de envío'].mean()

# Unimos todo en un solo DataFrame
resumen = pd.DataFrame({
    'Facturación Total (USD)': facturacion,
    'Calificación Promedio': calificacion,
    'Costo Envío Promedio (USD)': envio
})

# Redondeamos para que se vea más bonito
resumen = resumen.round(2)

# Ordenamos por facturación de mayor a menor
resumen = resumen.sort_values('Facturación Total (USD)', ascending=False)


# Mostramos la tabla
resumen
# Out:
#                  Facturación Total (USD)  Calificación Promedio  \
# Lugar de Compra
# Bogotá                       440005000.0                   4.09
# Medellín                     296858100.0                   3.87
# Cali                         154493700.0                   3.99
# Pereira                       56214300.0                   3.95
# Cúcuta                        37879500.0                   3.88
# Barranquilla                  32907700.0                   3.57
# Cartagena                     22296700.0                   4.04
# Riohacha                      18512700.0                   3.45
# Bucaramanga                   17579200.0                   4.39
# Pasto                         14996400.0                   4.04
# Leticia                       14669800.0                   4.16
# Santa Marta                   13198300.0                   3.75
# Manizales                      8027600.0                   3.80
# ...

# %%
# !pip install tabulate
from tabulate import tabulate

# Mostramos el resumen en formato tabla
print(tabulate(resumen, headers='keys', tablefmt='pretty'))
# Out:
# ...
# +-----------------+-------------------------+-----------------------+----------------------------+
# | Lugar de Compra | Facturación Total (USD) | Calificación Promedio | Costo Envío Promedio (USD) |
# +-----------------+-------------------------+-----------------------+----------------------------+
# |     Bogotá      |       440005000.0       |         4.09          |          23815.85          |
# |    Medellín     |       296858100.0       |         3.87          |          28207.1           |
# |      Cali       |       154493700.0       |         3.99          |          28827.56          |
# |     Pereira     |       56214300.0        |         3.95          |          22403.76          |
# |     Cúcuta      |       37879500.0        |         3.88          |          40129.41          |
# |  Barranquilla   |       32907700.0        |         3.57          |          23708.0           |
# ...
